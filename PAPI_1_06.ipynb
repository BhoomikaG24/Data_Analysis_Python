# %%
import requests

# %%
page2=requests.get('http://api.coincap.io/v2/assets')
print(page2)
# Out:
# <Response [200]>

# %%
result2=page2.json()

# %%
print(result2)
# Out:
# {'data': [{'id': 'bitcoin', 'rank': '1', 'symbol': 'BTC', 'name': 'Bitcoin', 'supply': '19839475.0000000000000000', 'maxSupply': '21000000.0000000000000000', 'marketCapUsd': '1699606416616.2133296983059700', 'volumeUsd24Hr': '9688194086.3796406315485425', 'priceUsd': '85667.9129168596109372', 'changePercent24Hr': '1.7346798341063258', 'vwap24Hr': '85533.7382785558726814', 'explorer': 'https://blockchain.info/'}, {'id': 'ethereum', 'rank': '2', 'symbol': 'ETH', 'name': 'Ethereum', 'supply': '120629195.4269564900000000', 'maxSupply': None, 'marketCapUsd': '240049264983.5519145414561935', 'volumeUsd24Hr': '5478259672.5220127499864314', 'priceUsd': '1989.9765072121929508', 'changePercent24Hr': '-1.8975329160695057', 'vwap24Hr': '2025.3801223126678792', 'explorer': 'https://etherscan.io/'}, {'id': 'xrp', 'rank': '3', 'symbol': 'XRP', 'name': 'XRP', 'supply': '58108919817.0000000000000000', 'maxSupply': '100000000000.0000000000000000', 'marketCapUsd': '144220268135.1206249591841933', 'volu
# ...

# %%
import pandas as pd

# %%
cd=result2['data']
adf=pd.DataFrame(cd)
adf.head()
# Out:
#              id rank symbol      name                         supply  \
# 0       bitcoin    1    BTC   Bitcoin      19839475.0000000000000000
# 1      ethereum    2    ETH  Ethereum     120629195.4269564900000000
# 2           xrp    3    XRP       XRP   58108919817.0000000000000000
# 3        tether    4   USDT    Tether  143653509034.0653000000000000
# 4  binance-coin    5    BNB       BNB     144006830.0000000000000000
#
#                        maxSupply                    marketCapUsd  \
# 0      21000000.0000000000000000  1699606416616.2133296983059700
# 1                           None   240049264983.5519145414561935
# 2  100000000000.0000000000000000   144220268135.1206249591841933
# 3                           None   143653577510.7778958801002229
# 4     144006830.0000000000000000    90010130989.0033583156884400
#
#                   volumeUsd24Hr                priceUsd    changePercent24Hr  \
# 0   9688194086.3796406315485425  85667.9129168596109372   1.7346798341063258
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
adf.to_csv(r"C:\Users\Bhoomika.G\OneDrive\Documents\result2.csv")

# %%
adf.head()
# Out:
#              id rank symbol      name                         supply  \
# 0       bitcoin    1    BTC   Bitcoin      19839475.0000000000000000
# 1      ethereum    2    ETH  Ethereum     120629195.4269564900000000
# 2           xrp    3    XRP       XRP   58108919817.0000000000000000
# 3        tether    4   USDT    Tether  143653509034.0653000000000000
# 4  binance-coin    5    BNB       BNB     144006830.0000000000000000
#
#                        maxSupply                    marketCapUsd  \
# 0      21000000.0000000000000000  1699606416616.2133296983059700
# 1                           None   240049264983.5519145414561935
# 2  100000000000.0000000000000000   144220268135.1206249591841933
# 3                           None   143653577510.7778958801002229
# 4     144006830.0000000000000000    90010130989.0033583156884400
#
#                   volumeUsd24Hr                priceUsd    changePercent24Hr  \
# 0   9688194086.3796406315485425  85667.9129168596109372   1.7346798341063258
# ...

# %%
adf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 100 non-null    object
#  1   rank               100 non-null    object
#  2   symbol             100 non-null    object
#  3   name               100 non-null    object
#  4   supply             100 non-null    object
#  5   maxSupply          44 non-null     object
#  6   marketCapUsd       100 non-null    object
#  7   volumeUsd24Hr      100 non-null    object
#  8   priceUsd           100 non-null    object
#  9   changePercent24Hr  100 non-null    object
#  10  vwap24Hr           98 non-null     object
#  11  explorer           89 non-null     object
# dtypes: object(12)
# memory usage: 9.5+ KB

# %%
adf.isnull()
# Out:
#        id   rank  symbol   name  supply  maxSupply  marketCapUsd  \
# 0   False  False   False  False   False      False         False
# 1   False  False   False  False   False       True         False
# 2   False  False   False  False   False      False         False
# 3   False  False   False  False   False       True         False
# 4   False  False   False  False   False      False         False
# ..    ...    ...     ...    ...     ...        ...           ...
# 95  False  False   False  False   False      False         False
# 96  False  False   False  False   False       True         False
# 97  False  False   False  False   False       True         False
# 98  False  False   False  False   False      False         False
# 99  False  False   False  False   False       True         False
#
#     volumeUsd24Hr  priceUsd  changePercent24Hr  vwap24Hr  explorer
# 0           False     False              False     False     False
# ...

# %%
adf.isnull().sum()
# Out:
# id                    0
# rank                  0
# symbol                0
# name                  0
# supply                0
# maxSupply            56
# marketCapUsd          0
# volumeUsd24Hr         0
# priceUsd              0
# changePercent24Hr     0
# vwap24Hr              2
# explorer             11
# dtype: int64

# %%
adf.dropna(inplace=True)
adf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 0 to 98
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 40 non-null     object
#  1   rank               40 non-null     object
#  2   symbol             40 non-null     object
#  3   name               40 non-null     object
#  4   supply             40 non-null     object
#  5   maxSupply          40 non-null     object
#  6   marketCapUsd       40 non-null     object
#  7   volumeUsd24Hr      40 non-null     object
#  8   priceUsd           40 non-null     object
#  9   changePercent24Hr  40 non-null     object
#  10  vwap24Hr           40 non-null     object
#  11  explorer           40 non-null     object
# dtypes: object(12)
# memory usage: 4.1+ KB

# %%
adf.isnull().sum()
# Out:
# id                   0
# rank                 0
# symbol               0
# name                 0
# supply               0
# maxSupply            0
# marketCapUsd         0
# volumeUsd24Hr        0
# priceUsd             0
# changePercent24Hr    0
# vwap24Hr             0
# explorer             0
# dtype: int64

# %%
adf.describe(include='all')
# Out:
#              id rank symbol     name                     supply  \
# count        40   40     40       40                         40
# unique       40   40     40       40                         40
# top     bitcoin    1    BTC  Bitcoin  19839400.0000000000000000
# freq          1    1      1        1                          1
#
#                         maxSupply                    marketCapUsd  \
# count                          40                              40
# unique                         33                              40
# top     21000000.0000000000000000  1704280625841.7085130145616000
# freq                            3                               1
#
#                        volumeUsd24Hr                priceUsd  \
# count                             40                      40
# unique                            40                      40
# top     10145644502.1455105855515613  85903.8391202207986640
# freq                               1                       1
#
# ...

# %% [markdown]
# # visulization

# %% [markdown]
# 1.histogram

# %%
plt.figure(figsize =(6,5))
sns.histplot(adf['rank'],kde=True,bins=15)
plt.title('distribution  of rank')
plt.show()

# %%
creat a scatter plot b/w plot price

# %%
import matplotlib.pyplot as plt
plt.scatter(adf['name'],adf['priceUsd'],color='k',label='price',marker='D')
plt.xlabel('name')
plt.ylabel('price')
plt.legend()

# %%
filter the where the data less than 2sg

# %%
adf['priceUsd']=adf['priceUsd'].astype(float)
ad=adf[adf['priceUsd']<2]
ad
# Out:
#                   id rank symbol                                   name  \
# 8            cardano    9    ADA                                Cardano
# 15           stellar   16    XLM                                Stellar
# 16  hedera-hashgraph   17   HBAR                                 Hedera
# 19         shiba-inu   20   SHIB                              Shiba Inu
# 32              pepe   33   PEPE                                   Pepe
# 39           vechain   40    VET                                VeChain
# 42             kaspa   43    KAS                                  Kaspa
# 43   crypto-com-coin   44    CRO                                 Cronos
# 51          algorand   52   ALGO                               Algorand
# 53            fantom   54      S                      Sonic (prev. FTM)
# 54           jupiter   55    JUP                                Jupiter
# 57             fetch   58    FET  Artificial Superintelligence Alliance
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(ad['name'],ad['priceUsd'],color='k',label='price',marker='D')
plt.xlabel('name')
plt.ylabel('price')
plt.legend()

# %%
subset=ad.loc[2:50,['priceUsd','name']]
print(subset.head(10))
# Out:
#     priceUsd       name
# 8   0.733159    Cardano
# 15  0.287957    Stellar
# 16  0.194397     Hedera
# 19  0.000013  Shiba Inu
# 32  0.000008       Pepe
# 39  0.026393    VeChain
# 42  0.080475      Kaspa
# 43  0.080989     Cronos

# %%
plt.figure(figsize=(10,5))
plt.scatter(ad['name'],ad['priceUsd'],color='green',label='price',marker='D')
plt.xlabel('name')
plt.ylabel('price')
plt.legend()
